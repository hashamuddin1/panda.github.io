# %% [markdown]
# <a href="https://colab.research.google.com/github/hashamuddin1/panda.github.io/blob/main/pandas_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-eed139df-346b-41e9-9736-54d72a319802" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eed139df-346b-41e9-9736-54d72a319802">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv.zip to data.csv (1).zip

# %%
import io

# %%
data=pd.read_csv("data.csv.zip")
data
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 1               1   20801  ...       11.0         €127.1M
# 2               2  190871  ...       11.0         €228.1M
# 3               3  193080  ...       94.0         €138.6M
# 4               4  192985  ...       13.0         €196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [18207 rows x 89 columns]

# %% [markdown]
# # **DISPLAY TOP 20 ROWS OF THE DATASET**

# %%
data.head(20)
# Out:
#     Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0            0  158023  ...        8.0         €226.5M
# 1            1   20801  ...       11.0         €127.1M
# 2            2  190871  ...       11.0         €228.1M
# 3            3  193080  ...       94.0         €138.6M
# 4            4  192985  ...       13.0         €196.4M
# 5            5  183277  ...        8.0         €172.1M
# 6            6  177003  ...        9.0         €137.4M
# 7            7  176580  ...       37.0           €164M
# 8            8  155862  ...       11.0         €104.6M
# 9            9  200389  ...       89.0         €144.5M
# 10          10  188545  ...       10.0         €127.1M
# 11          11  182521  ...       10.0         €156.8M
# 12          12  182493  ...       15.0          €90.2M
# 13          13  168542  ...       12.0           €111M
# 14          14  215914  ...       10.0         €121.3M
# 15          15  211110  ...        8.0         €153.5M
# ...

# %% [markdown]
# ## **CHECK LAST 20 ROWS OF THE DATA SET**

# %%
data.tail(20)
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 18187       18187  240158  ...       12.0            €66K
# 18188       18188  240927  ...       10.0           €143K
# 18189       18189  240160  ...        8.0           €125K
# 18190       18190  245569  ...        8.0           €165K
# 18191       18191  245570  ...       12.0           €119K
# 18192       18192  245571  ...       13.0           €119K
# 18193       18193  244823  ...       11.0            €99K
# 18194       18194  245862  ...       44.0           €109K
# 18195       18195  243582  ...       13.0           €153K
# 18196       18196  238477  ...        8.0           €113K
# 18197       18197  246167  ...       15.0            €88K
# 18198       18198  242844  ...       48.0           €165K
# 18199       18199  244677  ...       15.0           €175K
# 18200       18200  231381  ...       11.0           €143K
# 18201       18201  243413  ...       13.0           €153K
# ...

# %% [markdown]
# ## **CHECK DATA TYPE OF EACH COLUMN**

# %%
data.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %% [markdown]
# # **CHECK IS THERE ANY NULL VALUE**

# %%
data.isnull()
# Out:
#        Unnamed: 0     ID   Name  ...  GKPositioning  GKReflexes  Release Clause
# 0           False  False  False  ...          False       False           False
# 1           False  False  False  ...          False       False           False
# 2           False  False  False  ...          False       False           False
# 3           False  False  False  ...          False       False           False
# 4           False  False  False  ...          False       False           False
# ...           ...    ...    ...  ...            ...         ...             ...
# 18202       False  False  False  ...          False       False           False
# 18203       False  False  False  ...          False       False           False
# 18204       False  False  False  ...          False       False           False
# 18205       False  False  False  ...          False       False           False
# 18206       False  False  False  ...          False       False           False
#
# ...

# %% [markdown]
# # **CHECK NUMBER OF NULL VALUES IN EACH COLUMN**

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %% [markdown]
# # **CHECK NUMBER OF ROWS AND COLUMNS**

# %%
data.shape
#(ROWS,COLUMNS)
# Out:
# (18207, 89)

# %% [markdown]
# # **FINDOUT HIGHEST DRIBBLING PLAYER**

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
data["Dribbling"].max()
# Out:
# 97.0

# %%
data.loc[data["Dribbling"]==97]
# Out:
#    Unnamed: 0      ID      Name  ...  GKPositioning GKReflexes Release Clause
# 0           0  158023  L. Messi  ...           14.0        8.0        €226.5M
#
# [1 rows x 89 columns]

# %% [markdown]
# # **FINDING LOWEST DRIBBLING PLAYER**

# %%
data["Dribbling"].min()
# Out:
# 4.0

# %%
data.loc[data["Dribbling"]==4]
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 8168         8168  201847  ...       66.0           €1.1M
# 11563       11563  239499  ...       69.0           €866K
# 17602       17602  231273  ...       58.0           €109K
# 17866       17866  232676  ...       54.0            €38K
#
# [4 rows x 89 columns]

# %% [markdown]
# # **FIND OUT AVERAGE DRIBBLING**

# %%
data["Dribbling"].mean()
# Out:
# 55.37100060576023

# %% [markdown]
# # **FETCH THE LIST OF THE PLAYER WHOSE PREFERRED FOOT IS LEFT**

# %%
data.loc[data["Preferred Foot"]=="Left"]
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 13             13  168542  ...       12.0           €111M
# 15             15  211110  ...        8.0         €153.5M
# 17             17  194765  ...       14.0         €165.8M
# 19             19  192119  ...       88.0         €113.7M
# ...           ...     ...  ...        ...             ...
# 18172       18172  243636  ...       46.0           €119K
# 18175       18175  243649  ...        7.0            €78K
# 18191       18191  245570  ...       12.0           €119K
# 18200       18200  231381  ...       11.0           €143K
# 18201       18201  243413  ...       13.0           €153K
#
# [4211 rows x 89 columns]

# %% [markdown]
# # **FETCH THE LIST OF FC BARCELONA PLAYERS**

# %%
data.loc[data["Club"]=="FC Barcelona"]
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 7               7  176580  ...       37.0           €164M
# 18             18  192448  ...       90.0         €123.3M
# 20             20  189511  ...       13.0         €105.6M
# 32             32  189242  ...        6.0         €147.7M
# 42             42  205600  ...       15.0         €121.1M
# 49             49  189332  ...       13.0          €77.9M
# 53             53  168651  ...        9.0          €95.3M
# 54             54  152729  ...        8.0          €69.7M
# 96             96  181872  ...        4.0          €53.3M
# 155           155  231443  ...       13.0            €90M
# 192           192  199564  ...       10.0          €56.3M
# 228           228  230658  ...       12.0          €73.1M
# 236           236  222737  ...        9.0          €70.9M
# 239           239  220440  ...        7.0          €58.5M
# ...
